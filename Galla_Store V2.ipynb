# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import csv
import warnings
warnings.filterwarnings('ignore')
sns.set(style='whitegrid',palette='hsv')
#IMPORTING THE ECXELL CSV DATASET

df=pd.read_csv("C:\\Users\\subba\\OneDrive\\Desktop\\COLLEGE\\DATA SCience project\\Galla-store-project\\sample_sales_data.csv")
df2=df.copy()

# %%
#df2.head(2)
sns.lmplot(x='total',y='unit_price',palette='magma',row='payment_type',col='customer_type',data=df2,size=5)

# %%
plt.pie(df['category'].value_counts(),autopct='%1.3f',radius=3,labels=['fruit', 'vegetables', 'refrigerated items', 'frozen',
        'spices and herbs', 'canned foods', 'packaged foods',
        'condiments and sauces', 'beverages', 'dairy', 'cheese', 'meat',
        'seafood', 'baked goods', 'baking', 'snacks', 'baby products', 'pets',
        'personal care', 'medicine', 'kitchen', 'cleaning products'])

plt.show()

# %%
df.head(10)
# Out:
#    Unnamed: 0                        transaction_id            timestamp  \
# 0           0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1           1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2           2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3           3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4           4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# 5           5  b5b3c8b9-f496-484d-aa30-4f2efb5ed56c  2022-03-07 17:59:47
# 6           6  4997b1ae-f5aa-4b9f-8fc8-22ad8f19837c  2022-03-07 19:36:57
# 7           7  bfffee68-0736-42af-bd3e-4ca77541b0d6  2022-03-07 19:03:20
# 8           8  ce50e984-90cd-4b47-8537-3a4e32e6d314  2022-03-07 11:34:32
# 9           9  f0700cc9-e6f5-4b9a-add4-05e64b4f495b  2022-03-07 09:20:12
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# ...

# %%
df['quantity']
# Out:
# 0       2
# 1       1
# 2       2
# 3       4
# 4       2
#        ..
# 7824    2
# 7825    1
# 7826    2
# 7827    4
# 7828    4
# Name: quantity, Length: 7829, dtype: int64

# %%
plt.figure(figsize=(20,7))
sns.distplot(df['unit_price'],rug=True)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.distplot(df['total'],rug=True)
plt.show()

# %%
x=df.filter(["quantity","total"])
#sns.pairplot(x)
plt.figure(figsize=(5,5))
sns.distplot(x)
plt.show()

# %%
df['transaction_id'].value_counts(ascending=True)
# Out:
# c5745fe1-d789-4585-8f08-c045e24b7255    1
# 774f15d8-60a2-40af-b606-6ed1ce51f732    1
# a2d037ec-2d52-4ff1-b1cc-e63124a98019    1
# 8c70d527-47dc-43f9-8c63-10ec33d4ec76    1
# 80388dcb-e76e-4987-ba79-b52e5660a1b8    1
#                                        ..
# dac75b41-86b8-4af0-a558-2a3d3ca4b8b3    1
# 27524be0-4fe7-4385-9b22-de269780936b    1
# 529fc350-6d32-4053-90d7-b4ca044319bb    1
# d96465a7-a411-490d-b7af-edd7a4112fc2    1
# 077ff9fb-9e16-40c1-9e3f-5d7c87a783e0    1
# Name: transaction_id, Length: 7829, dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0   unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000  7829.000000
# mean   3914.000000     7.819480     2.501597    19.709905
# std    2260.181962     5.388088     1.122722    17.446680
# min       0.000000     0.190000     1.000000     0.190000
# 25%    1957.000000     3.990000     1.000000     6.570000
# 50%    3914.000000     7.190000     3.000000    14.970000
# 75%    5871.000000    11.190000     4.000000    28.470000
# max    7828.000000    23.990000     4.000000    95.960000

# %% [markdown]
# # Customer Requirements

# %% [raw]
# 1.They want to know how to better stock the items that they sell.
#
# 2."Can we accurately predict the stock levels of the products based on sales data and sensor data on horuly basis in order to more intelligently procure from our suppliers?"

# %% [markdown]
# # Ideas

# %% [raw]
# 1. According to given data set, first we must find the maximum sale of each category (acc to given timestamp info)
# this gives us the basic idea of maximum possible range of the sales in particular category and also we will know the minimum stock requirement of each category accordingly.
# 1a. create a data set with only specified columns of timestamp(any single day) and category which shows us the sales of the category on the particular day
#
# 2.

# %% [markdown]
# # Observed points

# %% [raw]
# 1) We are given only 7 days data(2022-03-01(9:51 am) to 2022-03-07(1:50pm))
#
# From the above pairplot and distplot of UNIT_PRICE and TOTAL,we observe that:-
#
# 2) customers show more tendency to buy the groceries upto 15$ sum
# 3) Customes at max tends to buy atmost 3 categories of goods i.e(most likely fruits,vegitables,refregirated items)
#
# 4)

# %%
df2=df
#df2[['timestamp','category']]
#df2.loc[df['timestamp'] == '2022-03-02']
#df2.loc[0:10,'timestamp'=='2022-03-02']

x=df2.filter(["timestamp","category"]) 
x
#x['category'].filter(like='fruit',axis=0)
#df3=(df2['date']<'2022-03-02')
#df3=df2.loc[df3]
#df3.head()
# Out:
#                 timestamp           category
# 0     2022-03-02 09:51:38              fruit
# 1     2022-03-06 10:33:59              fruit
# 2     2022-03-04 17:20:21              fruit
# 3     2022-03-02 17:23:58              fruit
# 4     2022-03-05 14:32:43              fruit
# ...                   ...                ...
# 7824  2022-03-03 18:22:09  cleaning products
# 7825  2022-03-04 19:14:46  cleaning products
# 7826  2022-03-03 14:00:09  cleaning products
# 7827  2022-03-04 15:11:38  cleaning products
# 7828  2022-03-06 13:50:36  cleaning products
#
# [7829 rows x 2 columns]

# %%
df2["date"]= pd.to_datetime(df2['timestamp']).dt.date
df2["time"]= pd.to_datetime(df2['timestamp']).dt.time
#df2.date.value_counts()
df2.head()
# Out:
#    Unnamed: 0                        transaction_id            timestamp  \
# 0           0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1           1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2           2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3           3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4           4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type        date      time
# ...

# %%
#c=df2.filter(["date","time"])
#c
df2['date'] = pd.to_datetime(df2['date'])
df2.head()
# Out:
#    Unnamed: 0                        transaction_id            timestamp  \
# 0           0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1           1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2           2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3           3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4           4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type       date      time
# ...

# %%
df2.dtypes
# Out:
# Unnamed: 0                 int64
# transaction_id            object
# timestamp                 object
# product_id                object
# category                  object
# customer_type             object
# unit_price               float64
# quantity                   int64
# total                    float64
# payment_type              object
# date              datetime64[ns]
# time                      object
# dtype: object

# %%
df3=df2[df2['date']=='2022-03-02']['time'].values[0:4]
df3
# Out:
# array([datetime.time(9, 51, 38), datetime.time(17, 23, 58),
#        datetime.time(15, 44, 48), datetime.time(14, 44, 45)], dtype=object)
